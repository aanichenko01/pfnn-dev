# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
# load data
v1_0 = np.load('C:/Users/Ana/Desktop/dev/pfnn-dev/pytorch-deepphase/LossHistoryGNN/v1.0_LossHist.npy')
v1_1 = np.load('C:/Users/Ana/Desktop/dev/pfnn-dev/pytorch-deepphase/LossHistoryGNN/v1.1_LossHist.npy')
v1_2 = np.load('C:/Users/Ana/Desktop/dev/pfnn-dev/pytorch-deepphase/LossHistoryGNN/v1.2_LossHist.npy')
v1_3 = np.load('C:/Users/Ana/Desktop/dev/pfnn-dev/pytorch-deepphase/LossHistoryGNN/v1.3_LossHist.npy')
v2_0 = np.load('C:/Users/Ana/Desktop/dev/pfnn-dev/pytorch-deepphase/LossHistoryGNN/v2.0_LossHist.npy')
v2_1 = np.load('C:/Users/Ana/Desktop/dev/pfnn-dev/pytorch-deepphase/LossHistoryGNN/v2.1_LossHist.npy')
v3_0 = np.load('C:/Users/Ana/Desktop/dev/pfnn-dev/pytorch-deepphase/LossHistoryGNN/v3.0_LossHist.npy')
# v3_1 = np.load('C:/Users/Ana/Desktop/dev/pfnn-dev/pytorch-deepphase/LossHistoryGNN/v3.1_LossHist.npy')
v3_2 = np.load('C:/Users/Ana/Desktop/dev/pfnn-dev/pytorch-deepphase/LossHistoryGNN/v3.2_LossHist.npy')

# add inf as first value (so epochs actually go to 20)
v1_0 = np.insert(v1_0, 0, np.inf)
v1_1 = np.insert(v1_1, 0, np.inf)
v1_2 = np.insert(v1_2, 0, np.inf)
v1_3 = np.insert(v1_3, 0, np.inf)
v2_0 = np.insert(v2_0, 0, np.inf)
v2_1 = np.insert(v2_1, 0, np.inf)
v3_0 = np.insert(v3_0, 0, np.inf)
# v3_1 = np.insert(v3_1, 0, np.inf)
v3_2 = np.insert(v3_2, 0, np.inf)

# Create corresponding x values
x = np.arange(len(v2_0))

# put everything on the same plot
plt.plot(x, v1_0, label='v1.0')
plt.plot(x, v1_1, label='v1.1')
plt.plot(x, v1_2, label='v1.2')
plt.plot(x, v1_3, label='v1.3')
# plt.plot(x, v2_0, label='v2.0')
# plt.plot(x, v2_1, label='v2.1')
plt.plot(x, v3_0, label='v3.0')
# plt.plot(x, v3_1, label='v3.1')
plt.plot(x, v3_2, label='v3.2')

# general formatting
plt.title('Training Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.xticks(np.arange(0, 151, 10))

# save_dir = 'C:/Users/Ana/Desktop/dev/pfnn-dev/pytorch-deepphase/LossPlots'
# name = 'v2.0'
# plt.savefig(save_dir + f'{name}_plot.png', dpi=300, bbox_inches='tight')

# show
plt.show()

# %%
# load data
v1_0 = np.load('C:/Users/Ana/Desktop/dev/pfnn-dev/pytorch-deepphase/LossHistoryGNN/v1.0_LossHist.npy')
v1_0_10 = np.load('C:/Users/Ana/Desktop/dev/pfnn-dev/pytorch-deepphase/LossHistoryGNN/v1.0_PAE10_LossHist.npy')
v4_0_10 = np.load('C:/Users/Ana/Desktop/dev/pfnn-dev/pytorch-deepphase/LossHistoryGNN/v4.0_PAE10_LossHist.npy')
v4_0_30 = np.load('C:/Users/Ana/Desktop/dev/pfnn-dev/pytorch-deepphase/LossHistoryGNN/v4.0_PAE30_LossHist.npy')


# add inf as first value (so epochs actually go to 20)
v1_0 = np.insert(v1_0, 0, np.inf)
v1_0_10 = np.insert(v1_0_10, 0, np.inf)
v4_0_10 = np.insert(v4_0_10, 0, np.inf)
v4_0_30 = np.insert(v4_0_30, 0, np.inf)

# Create corresponding x values
x = np.arange(len(v1_0))

# put everything on the same plot
plt.plot(x, v1_0, label='v1.0 PAE 30')
plt.plot(x, v1_0_10, label='v1.0 PAE 10')
plt.plot(x, v4_0_10, label='v4.0 PAE 10')
plt.plot(x, v4_0_30, label='v4.0 PAE 30')

# general formatting
plt.title('Training Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.xticks(np.arange(0, 151, 10))

# save_dir = 'C:/Users/Ana/Desktop/dev/pfnn-dev/pytorch-deepphase/LossPlots'
# name = 'v2.0'
# plt.savefig(save_dir + f'{name}_plot.png', dpi=300, bbox_inches='tight')

# show
plt.show()
