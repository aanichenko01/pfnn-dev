# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
# load data
v1_0 = np.load('C:/Users/Ana/Desktop/dev/pfnn-dev/TrainingStats/4_data_aug/root_traj/v1.0_LR1e-4_losshist.npy')
v2_0 = np.load('C:/Users/Ana/Desktop/dev/pfnn-dev/TrainingStats/4_data_aug/root_traj/v2.0_LR1e-4_losshist.npy')
v2_1_lr4 = np.load('C:/Users/Ana/Desktop/dev/pfnn-dev/TrainingStats/4_data_aug/root_traj/v2.1_LR1e-4_losshist.npy')
v2_1_lr5 = np.load('C:/Users/Ana/Desktop/dev/pfnn-dev/TrainingStats/4_data_aug/root_traj/v2.1_LR1e-5_losshist.npy')
v2_2_lr5 = np.load('C:/Users/Ana/Desktop/dev/pfnn-dev/TrainingStats/4_data_aug/root_traj/v2.2_LR1e-5_losshist.npy')
v2_2_lr6 = np.load('C:/Users/Ana/Desktop/dev/pfnn-dev/TrainingStats/4_data_aug/root_traj/v2.2_LR1e-6_losshist.npy')

# add inf as first value (so epochs actually go to 20)
v1_0 = np.insert(v1_0, 0, np.inf)
v2_0 = np.insert(v2_0, 0, np.inf)
v2_1_lr4 = np.insert(v2_1_lr4, 0, np.inf)
v2_1_lr5 = np.insert(v2_1_lr5, 0, np.inf)
v2_2_lr5 = np.insert(v2_2_lr5, 0, np.inf)
v2_2_lr6 = np.insert(v2_2_lr6, 0, np.inf)

# Create corresponding x values
x = np.arange(len(v1_0))

# put everything on the same plot
plt.plot(x, v1_0, label='3 jump clips: lr=1e-4')
plt.plot(x, v2_0, label='14 jump clips: lr=1e-4')
plt.plot(x, v2_1_lr4, label='48 jump clips: lr=1e-4')
plt.plot(x, v2_1_lr5, label='48 jump clips: lr=1e-5')
plt.plot(x, v2_2_lr5, label='120 jump clips: lr=1e-5')
plt.plot(x, v2_2_lr6, label='120 jump clips: lr=1e-6')

# general formatting
plt.title('Training Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.xticks(np.arange(0, 21, 5))

save_dir = 'C:/Users/Ana/Desktop/ReportContent/4 Data Aug Chapter/plots/'
plt.savefig(save_dir + 'root_traj_data_aug_loss_plot.png', dpi=300, bbox_inches='tight')

# show
plt.show()
